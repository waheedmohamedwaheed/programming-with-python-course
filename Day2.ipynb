# %%
print('hello')
# Out:
# hello

# %%
#con= mments
#print('hello')

# %%
#variable 
x=5
y='we school'
print(x)
print(y)
print('x')
# Out:
# 5
# we school
# x

# %%
x=3
X=5
print(x)
print(X)
# Out:
# 3
# 5

# %%
x,y,z='red','blue','green'
print(x)
print(y)
print(z)
# Out:
# red
# blue
# green

# %%
x=y=z='orange'
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
x="awesome"
print("python is"+ x)
# Out:
# python isawesome

# %%
text='future career camp , pyhon , group 4'
print(len(text))
print('camp' in text)
print(text.upper())
print(text.lower())
print(text.strip())
print(text.splite(","))
print(text.replace("4","5"))
# Out:
# 36
# True
# FUTURE CAREER CAMP , PYHON , GROUP 4
# future career camp , pyhon , group 4
# future career camp , pyhon , group 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ede147a3bc98> in <module>
#       5 print(text.lower())
#       6 print(text.strip())
# ----> 7 print(text.splite(","))
#       8 print(text.replace("4","5"))
#
# AttributeError: 'str' object has no attribute 'splite'

# %%
x="camp"
y="python"
z=4
print("future career {} , {} , group {} ".format(x,y,z))
print("hello{}".format("world"))
# Out:
# future career camp , python , group 4
# helloworld

# %%
x=6
x=1000000
x=5.8
x=.0

# %%
print(5-2)
# Out:
# 3

# %%
#integer
print(5/2)
# Out:
# 2.5

# %%
#float
print(5//2)
# Out:
# 2

# %%
print(5%2)
# Out:
# 1

# %%
print(4%2)
# Out:
# 0

# %%
print(5+3/2*(3-1))
# Out:
# 8.0

# %% [raw]
# x="we school"
# print(type(x))

# %%
x=5
y=6.5
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
y=int(2.8)
print(y)
# Out:
# 2

# %%
x=float(5)
print(x)
# Out:
# 5.0

# %%
z=str(5)
print(z)
print(type(z))
# Out:
# 5
# <class 'str'>

# %%
name=input("type your name")
print(type(name))
# Out:
# type your name waheed
# <class 'str'>

# %%
x=input("type a number")
print(type(x))
y=int(x)
y+3
# Out:
# type a number 5
# <class 'str'>
# 8

# %%
a=input("type a number")
# Out:
# type a number 6

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
b=int(a)
print(type(b))
# Out:
# <class 'int'>

# %%
b+5
# Out:
# 11

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
x=False
print(type(x))
# Out:
# <class 'bool'>

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
x=["maths","IT","physics","communication","PE"]
print(x)
# Out:
# ['maths', 'IT', 'physics', 'communication', 'PE']

# %%
x=["maths","IT","physics","communication","IT"]
x.append("arabic")
print(x)
# Out:
# ['maths', 'IT', 'physics', 'communication', 'IT', 'arabic']

# %%
y=[5,8,1,4,10]
y.sort()
print(y)
# Out:
# [1, 4, 5, 8, 10]

# %%
y=[5,8,1,4,10]
y.sort(reverse=True)
print(y)
# Out:
# [10, 8, 5, 4, 1]
