# %%
print("Hello")
# Out:
# Hello

# %%
4+2
# Out:
# 6

# %%
2+2
# Out:
# 4

# %%
print("Hello")
# Out:
# Hello

# %%
print("we school")
# Out:
# we school

# %%
#print("Hello")

# %%
''''
print('hello')
print('weschool')
''''
# Out:
#   File "<ipython-input-7-9ac28fb4310f>", line 4
#     ''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
x=5
print("x")
print(x)
# Out:
# x
# 5

# %%
name='waheed'
print(name)
print('name')
# Out:
# waheed
# name

# %%
x=6
y="helllo"
print(x)
print(y)
# Out:
# 6
# helllo

# %%
#overwrite
x=4
x=5
print(x)
# Out:
# 5

# %%
x=4
X-5
print(x)
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3e65545854b2> in <module>
#       1 x=4
# ----> 2 X-5
#       3 print(x)
#       4 print(X)
#
# NameError: name 'X' is not defined

# %%
name=4
name1=5
name_1=6
print(name)
print(name1)
print(name_1)
# Out:
# 4
# 5
# 6

# %%
x=5
y=6
print(x+y)
# Out:
# 11

# %%
x,y,z='orange','banana','apple'
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# apple

# %%
x=y=z="orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
x="awesome"
print('python is'+x)
# Out:
# python isawesome

# %%
x='python is'
y='awesome'
print(x+y)
# Out:
# python isawesome

# %%
print('python is awesome')
# Out:
# python is awesome

# %%
a='future career camp'
print(len(a))
# Out:
# 18

# %%
x='future career camp'
print('python'in x)
# Out:
# False

# %%
a='we school'
print(a.upper())
# Out:
# WE SCHOOL

# %%
a='WE SCHOOL'
a.lower()
# Out:
# 'we school'

# %%
a= '     we school            '
print(a.strip())
# Out:
# we school

# %%
x='we school grade 1'
x.replace("1","2")
# Out:
# 'we school grade 2'

# %%
y="we,school,grade,2"

y.split(" ")
# Out:
# ['we,school,grade,2']
